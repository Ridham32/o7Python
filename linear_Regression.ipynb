# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AUDIO.csv")

# %%
df.head()
# Out:
#   ticker        date    open    high     low   close
# 0  AUDIO  2021-01-08  0.1806  0.1920  0.1766  0.1917
# 1  AUDIO  2021-01-09  0.1917  0.1951  0.1744  0.1833
# 2  AUDIO  2021-01-10  0.1833  0.2095  0.1822  0.1931
# 3  AUDIO  2021-01-11  0.1931  0.1954  0.1612  0.1681
# 4  AUDIO  2021-01-12  0.1681  0.1812  0.1660  0.1694

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  928 non-null    object
#  1   date    928 non-null    object
#  2   open    928 non-null    float64
#  3   high    928 non-null    float64
#  4   low     928 non-null    float64
#  5   close   928 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 43.6+ KB

# %%
df.drop(["ticker","date"],axis=1,inplace=True)

# %%
df.head()
# Out:
#      open    high     low   close
# 0  0.1806  0.1920  0.1766  0.1917
# 1  0.1917  0.1951  0.1744  0.1833
# 2  0.1833  0.2095  0.1822  0.1931
# 3  0.1931  0.1954  0.1612  0.1681
# 4  0.1681  0.1812  0.1660  0.1694

# %%
sns.scatterplot(df,x="open",y="high")
# Out:
# <Axes: xlabel='open', ylabel='high'>

# %%
sns.scatterplot(df,x="close",y="high")
# Out:
# <Axes: xlabel='close', ylabel='high'>

# %%
sns.scatterplot(df,x="close",y="low")
# Out:
# <Axes: xlabel='close', ylabel='low'>

# %%
sns.scatterplot(df,x="open",y="low")
# Out:
# <Axes: xlabel='open', ylabel='low'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar = MinMaxScaler()

# %%
scalar.fit(df[["open","high","low","close"]])
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#      open    high     low   close
# 0  0.1806  0.1920  0.1766  0.1917
# 1  0.1917  0.1951  0.1744  0.1833
# 2  0.1833  0.2095  0.1822  0.1931
# 3  0.1931  0.1954  0.1612  0.1681
# 4  0.1681  0.1812  0.1660  0.1694

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop("close",axis=1)
y= df["close"]

# %%
y
# Out:
# 0      0.191700
# 1      0.183300
# 2      0.193100
# 3      0.168100
# 4      0.169400
#          ...
# 923    0.185620
# 924    0.185698
# 925    0.179580
# 926    0.178288
# 927    0.180805
# Name: close, Length: 928, dtype: float64

# %%
df
# Out:
#          open      high       low     close
# 0    0.180600  0.192000  0.176600  0.191700
# 1    0.191700  0.195100  0.174400  0.183300
# 2    0.183300  0.209500  0.182200  0.193100
# 3    0.193100  0.195400  0.161200  0.168100
# 4    0.168100  0.181200  0.166000  0.169400
# ..        ...       ...       ...       ...
# 923  0.184802  0.186698  0.183624  0.185620
# 924  0.185819  0.188294  0.179523  0.185698
# 925  0.185696  0.186798  0.175984  0.179580
# 926  0.179778  0.181280  0.177189  0.178288
# 927  0.178584  0.182600  0.174569  0.180805
#
# [928 rows x 4 columns]

# %%
x
# Out:
#          open      high       low
# 0    0.180600  0.192000  0.176600
# 1    0.191700  0.195100  0.174400
# 2    0.183300  0.209500  0.182200
# 3    0.193100  0.195400  0.161200
# 4    0.168100  0.181200  0.166000
# ..        ...       ...       ...
# 923  0.184802  0.186698  0.183624
# 924  0.185819  0.188294  0.179523
# 925  0.185696  0.186798  0.175984
# 926  0.179778  0.181280  0.177189
# 927  0.178584  0.182600  0.174569
#
# [928 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# x_train,y_train will predict the values

# %%
x_train
# Out:
#          open      high       low
# 844  0.286077  0.294053  0.274929
# 522  0.296590  0.316544  0.272593
# 922  0.186098  0.188691  0.183896
# 22   0.209000  0.220200  0.207000
# 398  1.163280  1.251120  1.082870
# ..        ...       ...       ...
# 289  2.135000  2.378000  2.120000
# 356  1.701340  1.713340  1.616160
# 647  0.189809  0.191306  0.182804
# 710  0.129505  0.130404  0.126100
# 493  0.491360  0.506442  0.418539
#
# [742 rows x 3 columns]

# %%
x_test
# Out:
#          open      high       low
# 804  0.265795  0.271666  0.262396
# 132  1.260000  1.505000  1.162000
# 840  0.300277  0.302421  0.289871
# 138  1.176000  1.294000  1.143000
# 360  1.642330  1.692170  1.578000
# ..        ...       ...       ...
# 737  0.186104  0.190802  0.184211
# 677  0.148884  0.154576  0.144538
# 795  0.243408  0.250231  0.237324
# 54   0.457100  0.526800  0.455800
# 64   1.012000  1.598000  0.976200
#
# [186 rows x 3 columns]

# %%
y_test
# Out:
# 804    0.268861
# 132    1.427000
# 840    0.293667
# 138    1.269000
# 360    1.602160
#          ...
# 737    0.184420
# 677    0.146332
# 795    0.247119
# 54     0.498300
# 64     1.463000
# Name: close, Length: 186, dtype: float64

# %%
y_train
# Out:
# 844    0.277303
# 522    0.287654
# 922    0.184802
# 22     0.214400
# 398    1.211850
#          ...
# 289    2.214000
# 356    1.656170
# 647    0.184800
# 710    0.127605
# 493    0.448371
# Name: close, Length: 742, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction= model.predict(x_test)

# %%
y_prediction
# Out:
# array([0.27161068, 1.31172195, 0.29885389, 1.22020007, 1.63282284,
#        2.84731118, 2.22895282, 0.32458731, 1.77755275, 0.20456885,
#        0.30391569, 2.04431612, 0.33486183, 0.74988683, 1.40363258,
#        0.1952024 , 2.45311237, 0.15095348, 0.30340261, 0.73423764,
#        2.1077943 , 0.17969935, 0.3061349 , 1.88695365, 0.34960327,
#        0.93209893, 2.39082566, 2.61518669, 0.2797447 , 0.30006424,
#        0.20908727, 0.39078675, 0.17765685, 3.23029616, 0.18626099,
#        0.18316318, 1.07600812, 0.15241813, 1.78265081, 0.17251522,
#        0.29801295, 0.18382442, 0.21428203, 0.69447457, 0.40507004,
#        1.98889184, 0.37842627, 0.15543719, 0.28353549, 1.11836614,
#        0.3513497 , 0.28264776, 1.41581308, 0.36418809, 1.0501814 ,
#        0.37990778, 0.41874708, 1.83358411, 0.1728556 , 2.55462755,
#        0.20555173, 0.78362022, 1.74530074, 2.26504718, 0.22316731,
#        2.30192138, 0.19661212, 0.28296266, 0.25601185, 2.3004435 ,
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_prediction)
mse
# Out:
# 0.00154133067361318

# %%
from sklearn.metrics import r2_score

# %%
r2Score = r2_score(y_test,y_prediction)
r2Score
# Out:
# 0.9977372559043179

# %%
import pickle

# %%
pickle.dump(model,open('model.pkl','wb'))
